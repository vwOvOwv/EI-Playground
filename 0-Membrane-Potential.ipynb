# %% [markdown]
# # Membrane Potential

# %% [markdown]
# ## 1. Nernst Potential

# %% [markdown]
# ***TL;DR:*** At equilibrium, fewer ions are at high energy while most at low energy, which results in a potential difference called Nernst potential in electric field.

# %% [markdown]
# ### 1.1. Thermal equilibrium and Boltzmann distribution

# %% [markdown]
# From the theory of thermodynamics we know that **at equilibrium**, the probability of a particle occupying a state with energy $E$ follows the Boltzmann distribution:
#
# \begin{align*}
# p(E)\propto \exp\left(-\frac{E}{kT}\right),
# \end{align*}
#
# where $p(E)$ is the probability of a particle having energy $E$, $k$ is the Boltzmann constant, and $T$ is the temperature.

# %% [markdown]
# <div style="background-color: #f1f7ff; border-left: 8px solid #67696dff; padding: 18px; border-radius: 4px; color: #333;">
#
# <b style="color: #67696dff; font-size: 1.2em; display: block; margin-bottom: 10px;">Step-by-step derivation of Boltzmann distribution through maximizing entropy. </b>
#
# Consider a system with $N$ states, each state $i$ has energy $E_i$ ($N$ and $E_i$ are constants). A particle can occupy any of these states. Let $p_i$ be the probability of the particle occupying state $i$. To achieve equilibrium, the system tends to minimize its free energy, which is equivalent to **maximizing its entropy (degree of random/disorder) under two constraints**:
# - Total probability sums to 1
#
# - Total energy is conserved
#
# The entropy $S$ is given by:
# $$S = -k \sum_{i=1}^{N} p_i \ln p_i,$$
# where $k$ is the Boltzmann constant.
#
# Now we formalize the optimization problem as follows:
#
# $$\mathrm{maximize\space} S, \mathrm{s.t.} \sum_{i=1}^{N} p_i = 1 \text{ and } \sum_{i=1}^{N} p_i E_i = U.$$
#
# Introduce Lagrange multipliers to solve the constrained optimization problem:
#
# $$\mathcal{L}(p_1, p_2, \ldots, p_N, \alpha, \beta) = -k \sum_{i=1}^{N} p_i \ln p_i - \alpha \left(\sum_{i=1}^{N} p_i - 1\right) - \beta \left(\sum_{i=1}^{N} p_i E_i - U\right).$$
# Taking the derivative of $\mathcal{L}$ with respect to each $p_i$ and setting it to zero gives
#
# $$\frac{\partial \mathcal{L}}{\partial p_j} = -k (\ln p_j + 1) - \alpha - \beta E_j.$$
#
# Setting the derivative to zero we obtain
#
# $$p_j = \exp\left(-1 - \frac{\alpha}{k}\right)\cdot\exp\left(- \frac{\beta E_j}{k}\right).$$
#
# Using the constraint $\sum_{i=1}^{N} p_i = 1$, we know
#
# $$\exp\left(-1 - \frac{\alpha}{k}\right) = \frac{1}{\sum_{i=1}^{N} \exp\left(- \frac{\beta E_i}{k}\right)}$$
#
# and thus $p_j = \frac{\exp\left(- \frac{\beta E_j}{k}\right)}{Z}$, where $Z = \sum_{i=1}^{N} \exp\left(- \frac{\beta E_i}{k}\right)$.
#
# Plugging $p_j$ back into $S$, we have
#
# $$S = -k\sum_{i=1}^N p_i\left(-\frac{\beta E_i}{k} - \ln Z\right) = k\ln Z + \beta U.$$
#
# Calculate the total derivative of $S$:
#
# \begin{align*}
# \mathrm dS &= \mathrm d(k\ln Z + \beta U) \\
# &= \frac{k}{Z} \cdot \mathrm dZ + \beta \mathrm dU + U \mathrm d\beta \\
# &= \frac{k}{Z} \cdot \left[ \sum_{i=1}^N \left(-\frac{E_i}{k}\right) \exp\left(- \frac{\beta E_i}{k}\right)\mathrm d\beta \right] + \beta \mathrm dU + U\mathrm d\beta \\
# &= \frac{-\sum_{i=1}^N E_i \exp\left(- \frac{\beta E_i}{k}\right) \mathrm d\beta}{Z} + \beta \mathrm dU + U\mathrm d\beta \\
# &= \frac{-(\sum_{i=1}^N E_i p_i Z) \mathrm d\beta}{Z} + \beta \mathrm dU + U\mathrm d\beta \\
# &= -U \mathrm d\beta + \beta \mathrm dU + U\mathrm d\beta \\
# &= \beta\mathrm dU. \end{align*}
#
# Therefore, $\frac{\mathrm dS}{\mathrm dU} = \beta$.
#
# Assuming the volume $V$ of the system is constant, from the first law of thermodynamics we have $dU = TdS$, which leads to $\frac{\mathrm dS}{\mathrm dU} = \frac{1}{T}$.
#
# Therefore, $\beta = \frac{1}{T}$ and thus
#
# $$p(E) = \frac{\exp\left(- \frac{E}{kT}\right)}{\sum_{i=1}^{N} \exp\left(- \frac{E_i}{kT}\right)},$$
#
# which is exactly the Boltzmann distribution.

# %% [markdown]
# ### 1.2. Nernst potential

# %% [markdown]
# In a static electric field, the energy level of a particle (ion) with charge $q$ at location $x$ is given by electric potential:
#
# \begin{align*}
# E = qu(x),
# \end{align*}
#
# where $u(x)$ is the potential at $x$.
#
# Interpreting the probability distribution $p(E)$ in terms of ion concentration $n(x)$, we have:
#
# \begin{align*}
# n(x)\propto \exp\left(-\frac{qu(x)}{kT}\right).
# \end{align*}
#
# For ions at two locations $x_1$ and $x_2$, we have:
#
# \begin{align*}
# \frac{n(x_1)}{n(x_2)} = \exp\left(-\frac{q[u(x_1)-u(x_2)]}{kT}\right).
# \end{align*}
# Thus, the potential difference $\Delta u = u(x_1) - u(x_2)$ is
#
# \begin{align*}
# \Delta u = -\frac{kT}{q}\ln\frac{n(x_1)}{n(x_2)},
# \end{align*}
#
# which is known as the Nernst potential.

# %% [markdown]
# <div style="background-color: #f1f7ff; border-left: 8px solid #67696dff; padding: 18px; border-radius: 4px; color: #333;">
#
# <b style="color: #67696dff; font-size: 1.2em; display: block; margin-bottom: 10px;">Figure: equilibrium between electric force and diffusion. </b>
#
# <p align="center">
#   <img src="./assets/nernst_potential.png" alt="Figure 1" width="50%">
# </p>

# %% [markdown]
# <div style="background-color: #f1f7ff; border-left: 8px solid #3b82f6; padding: 18px; border-radius: 4px; color: #333;">
#
# <b style="color: #1e40af; font-size: 1.2em; display: block; margin-bottom: 10px;">Practice: Nernst potential of sodium (Na⁺) and potassium (K⁺).</b>
#
# Given the following constants
#
# \begin{align*}
# q &= 1.6 \times 10^{-19} \mathrm{C}, \\
# k &= 1.4 \times 10^{-23} \mathrm{J/K}, \\
# T &= 298 \mathrm{K},
# \end{align*}
#
# calculate the reversal potentials for sodium (Na⁺) and potassium (K⁺) ions, given their common intracellular and extracellular concentrations at equilibrium.
#
# | Ion | Intracellular (mM) | Extracellular (mM) |
# |-----|----------------------------------|----------------------------------|
# | Na⁺ | 10                               | 145                              |
# | K⁺  | 140                              | 5                                |
#
# Note that there is more sodium outside the cell than inside, while the reverse is true for potassium.

# %% [markdown]
# <div style="background-color: #f1f7ff; border-left: 8px solid #f6643bff; padding: 18px; border-radius: 4px; color: #333;">
#
# <b style="color: #f6643bff; font-size: 1.2em; display: block; margin-bottom: 10px;">Answer</b>
#
# Let the intracellular location be $x_1$ and the extracellular location be $x_2$. From Nernst equation we obtain
#
# \begin{align*}
# E_\mathrm{Na} &= -\frac{kT}{q}\ln\frac{n(x_{1,\mathrm{Na}})}{n(x_{2,\mathrm{Na}})} \approx 69.7 \mathrm{mV} \\
# E_\mathrm{K} &= -\frac{kT}{q}\ln\frac{n(x_{1,\mathrm{K}})}{n(x_{2,\mathrm{K}})} \approx -86.9 \mathrm{mV}
# \end{align*}
#
# Note that here the Nernst potential is defined as **the potential inside the cell minus that outside the cell**.
#
# We can observe that at equilibrium, lower ion concentration corresponds to higher potential, which aligns with our discussion above.

# %% [markdown]
# ## 2. Ion Pumps and Channels

# %% [markdown]
# ***TL;DR:*** Ion pumps consume energy to maintain concentration gradients, while ion channels use these gradients to create electric potentials by passively transporting ions across membrane.

# %% [markdown]
# ### 2.1. Ion pumps

# %% [markdown]
# In the practice above, we can observe that there are much higher concentrations of K⁺ inside the cell and Na⁺ outside the cell. So why and how do cells collect K⁺ while evicting Na⁺?
#
# The reason for such phenomenon may be attributed to evolution. One of the hypotheses is that life originated in a K⁺-rich environment (unlike today's ocean, which is rich in Na⁺), making it easy for cells to retain K⁺ and keep them inside the membrane. And K⁺ is utilized by many cellular organelles and processes, making it essential for life. As time goes by, environment changed and Na⁺ became more and more while K⁺ got less (especially in ocean). To Adapt to such changes, cells evolved specialized proteins called Na⁺-K⁺ pump that **actively** imports K⁺ and exports Na⁺.
#
# Here we take the concentration gradients of Na⁺ and K⁺ as given facts due to the existence of Na⁺-K⁺ pump, and focus on how potential difference across the membrane is generated and maintained in the following sections.

# %% [markdown]
# ### 2.2. Ion channels

# %% [markdown]
# Neurons also have specialized proteins called ion channels embedded in their membranes that allow specific ions to pass through **without consuming energy** (e.g., ATP). These channels can be selective for certain ions (e.g., Na⁺, K⁺, Ca²⁺, Cl⁻) and can open or close in response to various stimuli, such as changes in voltage (voltage-gated channels), binding of a ligand (ligand-gated channels), or mechanical forces (mechanically-gated channels).
#
# As we will see in the next section, ion channels play a crucial role in generating the membrane potential by allowing ions to move across the membrane according to their concentration gradients established by the ion pumps.

# %% [markdown]
# ### 2.3. Generation of potential difference across membrane

# %% [markdown]
# Let's start from an idealized neuron. There is only K⁺ inside and outside the cell and there is no Na⁺. K⁺ is more inside the cell and can move across the membrane through K⁺ channels freely.
#
# At the beginning, K⁺ ions tend to diffuse from inside to outside the cell due to the concentration gradient. As K⁺ ions leave the cell, the inside of the cell becomes negatively charged while the outside becomes positively charged. This charge separation creates an electric field across the membrane that opposes further diffusion of K⁺ ions.
#
# When the electric force pushing K⁺ ions back into the cell balances the diffusion process, the system reaches equilibrium, and the potential difference will be exactly the Nernst potential for K⁺ ions calculated above.

# %% [markdown]
# <div style="background-color: #f1f7ff; border-left: 8px solid #67696dff; padding: 18px; border-radius: 4px; color: #333;">
#
# <b style="color: #67696dff; font-size: 1.2em; display: block; margin-bottom: 10px;">Figure: generation of potential difference. </b>
#
# <p align="center">
#   <img src="./assets/potential_generation.png" alt="Figure 1" width="90%">
# </p>

# %% [markdown]
# Note that this process reaches equilibrium, and can be maintained permanently without consuming energy.

# %% [markdown]
# ## 3. Resting and Reversal Potential

# %% [markdown]
# ***TL;DR:*** TODO

# %% [markdown]
# ### 3.1. Neurons as a non-equilibrium system

# %% [markdown]
# TODO: steady state vs equilibrium;

# %% [markdown]
# ### 3.2. Resting potential

# %% [markdown]
# ### 3.3. Reversal Potential
